# %%
from datetime import datetime
import cv2

cap = cv2.VideoCapture('rtsp://admin:admin@192.168.2.103:554/cam/realmonitor?channel=1&subtype=0')

width= int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height= int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

writer= cv2.VideoWriter(f"piggies_{datetime.now()}.mp4", cv2.VideoWriter_fourcc(*'MP4V'), 20, (width,height))

img_counter = 0

while (1):
    frameId = cap.get(1)
    ret, frame = cap.read()

    writer.write(frame)

    cv2.imshow("Video", frame)

    k = cv2.waitKey(1) & 0xff
    if k == 27:

        break


cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# QObject::moveToThread: Current thread (0x5594374f7920) is not the object's thread (0x559436c542e0).
# Cannot move to target thread (0x5594374f7920)
#
# QObject::moveToThread: Current thread (0x5594374f7920) is not the object's thread (0x559436c542e0).
# Cannot move to target thread (0x5594374f7920)
#
# QObject::moveToThread: Current thread (0x5594374f7920) is not the object's thread (0x559436c542e0).
# Cannot move to target thread (0x5594374f7920)
#
# QObject::moveToThread: Current thread (0x5594374f7920) is not the object's thread (0x559436c542e0).
# Cannot move to target thread (0x5594374f7920)
#
# QObject::moveToThread: Current thread (0x5594374f7920) is not the object's thread (0x559436c542e0).
# Cannot move to target thread (0x5594374f7920)
#
# ...

# %%
import cv2

cap = cv2.VideoCapture('recording_03/recording.mp4')

img_counter = 236
counter = 0
while 1:

    success, frame = cap.read()
    if success:
        cv2.imwrite(f"recording_03/piggies_{img_counter}.jpg", frame)
        counter += 60
        cap.set(cv2.CAP_PROP_POS_FRAMES, counter)

    else:
        break
    img_counter+=1



cap.release()

# %%
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/gabemanfroi/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     code_obj : code object
#   File "/tmp/ipykernel_237258/1062762171.py", line 1, in <cell line: 1>
#     from tflite_model_maker import image_classifier
#   File "/home/gabemanfroi/anaconda3/lib/python3.9/site-packages/tflite_model_maker/__init__.py", line 44, in <module>
#     from tflite_model_maker import audio_classifier
#   File "/home/gabemanfroi/anaconda3/lib/python3.9/site-packages/tflite_model_maker/audio_classifier/__init__.py", line 24, in <module>
#     from tensorflow_examples.lite.model_maker.core.data_util.audio_dataloader import DataLoader
#   File "/home/gabemanfroi/anaconda3/lib/python3.9/site-packages/tensorflow_examples/lite/model_maker/core/data_util/audio_dataloader.py", line 27, in <module>
# ...

# %%
from tflite_model_maker import image_classifier
# Out:
# 1
